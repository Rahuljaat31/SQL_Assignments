# %% [markdown]
# Q-17. Write an SQL query to show the top n (say 10) records of a table.

# %%
#Ans.17 below is the query
#SELECT * FROM worker ORDER BY ID DESC LIMIT 10;

from IPython.display import Image
Image(filename='assignment9ex1.jpg')#adding screenshot for reference

# %%
from IPython.display import Image
Image(filename='assignment9ex2.jpg')#adding screenshot for reference showing desired results

# %% [markdown]
# Q-18. Write an SQL query to determine the nth (say n=5) highest salary from a table.

# %%
#Ans.8 Below is the query

#SELECT salary FROM customers ORDER BY salary DESC LIMIT 0, 5;

from IPython.display import Image
Image(filename='salary.jpg')#adding screenshot for reference

# %%
from IPython.display import Image
Image(filename='salary1.jpg')#adding screenshot for reference
