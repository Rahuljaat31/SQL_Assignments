# %% [markdown]
# Q-19. Write an SQL query to determine the 5th highest salary without using TOP or limit method.

# %%
#Ans.19 Below is the query

#SELECT * FROM Customers ORDER BY salary DESC LIMIT 4,1;
from IPython.display import Image
Image(filename='salary.jpg')#adding screenshot for reference

# %%
#Output for 5th highest salary
from IPython.display import Image
Image(filename='sal5thh.jpg')#adding screenshot for reference

# %% [markdown]
# Q-20. Write an SQL query to fetch the list of employees with the same salary.

# %%
#Ans.20
#Adding same salary to table for example
from IPython.display import Image
Image(filename='samesal.jpg')#adding screenshot for reference after adding same salary

# %%
#Ans.20 below is the query

#SELECT Name, salary FROM customers WHERE Salary IN ( SELECT Salary FROM customers GROUP BY Salary HAVING COUNT(*) > 1 );

from IPython.display import Image
Image(filename='samesal1.jpg')#adding screenshot after executing above query for same salary
